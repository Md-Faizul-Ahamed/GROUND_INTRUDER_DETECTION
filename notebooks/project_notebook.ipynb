# %%
import pandas as pd
data = pd.read_csv('C:\SURVEILLANCE_HUMAN_DETECTION\data\synthetic_sensor_dataset.csv')
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\S'
# <>:2: SyntaxWarning: invalid escape sequence '\S'
# C:\Users\hp\AppData\Local\Temp\ipykernel_10740\3639960567.py:2: SyntaxWarning: invalid escape sequence '\S'
#   data = pd.read_csv('C:\SURVEILLANCE_HUMAN_DETECTION\data\synthetic_sensor_dataset.csv')

# %%
import src.data_processing as dp
X, y = dp.preprocess_data(data)

# %%
import src.model_training as mt
model, X_test, y_test = mt.train_model(X, y)

# %%
import src.model_evaluation as me
me.evaluate_model(X_test, y_test)
# Out:
# Accuracy: 0.97
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.98      0.98      0.98       188
#            1       0.75      0.75      0.75        12
#
#     accuracy                           0.97       200
#    macro avg       0.87      0.87      0.87       200
# weighted avg       0.97      0.97      0.97       200
#
# Confusion Matrix:
#  [[185   3]
#  [  3   9]]

# %%
import src.visualization as vz
vz.visualize_tree()
